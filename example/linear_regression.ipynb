# %% [markdown]
# # Data Preperation

# %% [markdown]
# ## 1. Data Set Selection

# %% [markdown]
# ### Sources to Acquire Datasets From

# %% [markdown]
# - [Kaggle](https://www.kaggle.com/datasets)

# %% [markdown]
# - [UCI Machine Learning Repository](https://archive.ics.uci.edu/)

# %% [markdown]
# - [Data.Gov](https://data.gov/)

# %% [markdown]
# - [World Bank Open Data](https://data.worldbank.org/)

# %% [markdown]
# - [Awesome Public Datsets](https://github.com/awesomedata/awesome-public-datasets)

# %% [markdown]
# ### Code Documentation

# %% [markdown]
# - [Numpy](https://numpy.org/)

# %% [markdown]
# - [Pandas](https://pandas.pydata.org/)

# %% [markdown]
# ## 2. Import the Dataset

# %%
import numpy as np
import pandas as pd

# %%
# Show all columns in Jupyter Lab using Pandas
pd.set_option('display.max_columns', None)

# %%
# Insert Dataset Here (Code to Be Completed)
df = pd.read_csv("database/AirQualityUCI.csv", sep=";")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Insert Dataset Here (Code to Be Completed)
# ----> 2 df = pd.read_csv("database/AirQualityUCI.csv", sep=";")
#
# File ~/Desktop/ML-Class/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
# ...

# %%
display(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 display(df)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 3. Look for Data that Needs to Be Dropped / Cleaned

# %%
# Drop Rows with NaN values ('how' indicates that all columns must contain NaN values to be dropped)
# Code to Be Completed Here
df.dropna(inplace=True, axis=1, how="all")
# Drop Columns with NaN values ('how' indicates that all rows must contain NaN values to be dropped)
# Code to Be Complete Here
df.dropna(inplace=True, axis=0, how="all")

# %%
df2 = df.drop(columns=["CO(GT)"], inplace=False)

# %%
display(df)
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9352  04/04/2005  10.00.00    3,1       1314.0    -200.0     13,5
# 9353  04/04/2005  11.00.00    2,4       1163.0    -200.0     11,4
# 9354  04/04/2005  12.00.00    2,4       1142.0    -200.0     12,4
# 9355  04/04/2005  13.00.00    2,1       1003.0    -200.0      9,5
# 9356  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...
